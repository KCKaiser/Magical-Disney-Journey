# %%
import os
from splinter import Browser
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)
from bs4 import BeautifulSoup as bs
import requests
import pymongo
import pandas as pd
import json

# %%
#Create MongoDB connection

import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
#Begin Scraping of NASA News
# URL of page to be scraped
#url = 'https://www.undercovertourist.com/orlando/crowd-calendar/October-2019/'

url = "https://www.undercovertourist.com/orlando/crowd-calendar/November-2018/"

# Retrieve page with the requests module
response = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup = bs(response.text, 'lxml')

# %%
title = soup.title.text

results_1 = soup.find('h1').text

print(results_1)
# Out:
# Orlando

# %%
a=soup.find('span',{'class':'daydetail crowdavg'}).text

t
# Out:
# [<div class="caleventslist">
#  <li>International Festival of the Holidays</li>
#  <li>Candlelight Processional</li>
#  </div>, <div class="caleventslist">
#  <li>Grinchmas</li>
#  <li>Christmas in The Wizarding World of Harry Potter™</li>
#  </div>, <div class="caleventslist">
#  <li>Christmas in The Wizarding World of Harry Potter™</li>
#  </div>, <div class="caleventslist">
#  <li>SeaWorld's Christmas Celebration</li>
#  </div>, <div class="caleventslist">
#  <li>Grinchmas</li>
#  <li>Christmas in The Wizarding World of Harry Potter™</li>
#  </div>, <div class="caleventslist">
#  <li>Christmas in The Wizarding World of Harry Potter™</li>
#  </div>, <div class="caleventslist">
#  <li>SeaWorld's Christmas Celebration</li>
#  </div>, <div class="caleventslist">
#  <li>Grinchmas</li>
#  <li>Christmas in The Wizarding World of Harry Potter™</li>
#  </div>, <div class="caleventslist">
#  <li>Christmas in The Wizarding World of Harry Potter™</li>
#  </div>, <div class="caleventslist">
# ...

# %%
B = soup.find()('span',{'class':'daydetail crowdavg'})

B
# Out:
# [<span class="daydetail crowdavg">4 - 6</span>,
#  <span class="daydetail crowdavg">6/10</span>,
#  <span class="daydetail crowdavg">5/10</span>,
#  <span class="daydetail crowdavg">5/10</span>,
#  <span class="daydetail crowdavg">4/10</span>,
#  <span class="daydetail crowdavg">5/10</span>,
#  <span class="daydetail crowdavg">5/10</span>,
#  <span class="daydetail crowdavg">6/10</span>,
#  <span class="daydetail crowdavg">5/10</span>,
#  <span class="daydetail crowdavg">5/10</span>,
#  <span class="daydetail crowdavg">5/10</span>,
#  <span class="daydetail crowdavg">4/10</span>,
#  <span class="daydetail crowdavg">5/10</span>,
#  <span class="daydetail crowdavg">6/10</span>,
#  <span class="daydetail crowdavg">6/10</span>,
#  <span class="daydetail crowdavg">5/10</span>,
#  <span class="daydetail crowdavg">4/10</span>,
#  <span class="daydetail crowdavg">4/10</span>,
#  <span class="daydetail crowdavg">4/10</span>,
#  <span class="daydetail crowdavg">6/10</span>,
# ...

# %%
t=soup.find()('div',{'class':'crowdavg'})

t
# Out:
# [<div class="day crowdavg">28</div>,
#  <div class="day crowdavg">29</div>,
#  <div class="day crowdavg">30</div>,
#  <div class="day crowdavg">31</div>,
#  <div class="day crowdavg">1</div>,
#  <div class="day crowdavg">2</div>,
#  <div class="day crowdavg">4</div>,
#  <div class="day crowdavg">5</div>,
#  <div class="day crowdavg">6</div>,
#  <div class="day crowdavg">7</div>,
#  <div class="day crowdavg">8</div>,
#  <div class="day crowdavg">9</div>,
#  <div class="day crowdavg">10</div>,
#  <div class="day crowdavg">11</div>,
#  <div class="day crowdavg">12</div>,
#  <div class="day crowdavg">13</div>,
#  <div class="day crowdavg">14</div>,
#  <div class="day crowdavg">15</div>,
#  <div class="day crowdavg">16</div>,
#  <div class="day crowdavg">26</div>,
#  <div class="day crowdavg">27</div>,
#  <div class="day crowdavg">28</div>,
#  <div class="day crowdavg">29</div>,
#  <div class="day crowdavg">30</div>,
#  <div class="day crowdavg">1</div>]

# %%
t=soup.find()('div',{'class':'caleventslist'})

t
# Out:
# [<div class="caleventslist">
#  <li>Mickey's Not So Scary Halloween Party</li>
#  </div>, <div class="caleventslist">
#  <li>Epcot International Food &amp; Wine Festival</li>
#  </div>, <div class="caleventslist">
#  <li>Halloween Horror Nights</li>
#  </div>, <div class="caleventslist">
#  <li>Seaworld's Halloween Spooktacular</li>
#  </div>, <div class="caleventslist">
#  <li>Epcot International Food &amp; Wine Festival</li>
#  </div>, <div class="caleventslist">
#  <li>Mickey's Not So Scary Halloween Party</li>
#  </div>, <div class="caleventslist">
#  <li>Epcot International Food &amp; Wine Festival</li>
#  </div>, <div class="caleventslist">
#  <li>Mickey's Not So Scary Halloween Party</li>
#  </div>, <div class="caleventslist">
#  <li>Epcot International Food &amp; Wine Festival</li>
#  </div>, <div class="caleventslist">
#  <li>Halloween Horror Nights</li>
#  </div>, <div class="caleventslist">
#  <li>Epcot International Food &amp; Wine Festival</li>
# ...
